# %%
# !pip install feature_engine
import pandas as pd
model_df = pd.read_pickle("model_churn_rf.pkl")
model_df
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 3.1 MB/s eta 0:00:00
# ...
# model       (DecisionTreeDiscretiser(regression=False,\n  ...
# features    [qtdeDiasD14, propAvgQtdeDias, qtdeDiasUltimaT...
# dtype: object

# %%
df = pd.read_csv("/content/abt_churn.csv")
df.head()
# Out:
#         dtRef                             idUsuario  qtdeTransacoes  qtdeDias  \
# 0  2024-06-01  000ff655-fa9f-4baa-a108-47f581ec52a1             266        27
# 1  2024-10-01  000ff655-fa9f-4baa-a108-47f581ec52a1             268        28
# 2  2024-04-01  000ff655-fa9f-4baa-a108-47f581ec52a1             188        11
# 3  2024-05-01  000ff655-fa9f-4baa-a108-47f581ec52a1             262        24
# 4  2024-08-01  001749bd-37b5-4b1e-8111-f9fbba90f530               1         1
#
#    mediaTransacoesDias  saldoPontos  qtdePontosPos  qtdePontosNeg  \
# 0             9.851852          635           2635          -2000
# 1             9.571429          686           2686          -2000
# 2            17.090909          275           1275          -1000
# 3            10.916667          484           2484          -2000
# 4             1.000000           50             50              0
#
#    qtdeDiasUltimaTransacao  qtdeDiasPrimeiraTransacao  ...  saldoPontosD28  \
# ...

# %%
amostra = df[df['dtRef']== df['dtRef'].max()].sample(5)

amostra
# Out:
#            dtRef                             idUsuario  qtdeTransacoes  \
# 5309  2025-04-01  f48aa032-94dc-4d0f-9b0f-7f61d5f913cf               2
# 990   2025-04-01  24782f0b-4683-4f35-976a-ea21d6714ba6            6904
# 1040  2025-04-01  268ed8e7-3c04-4865-8594-8d0254954a35               1
# 1684  2025-04-01  433a5751-70f6-4329-be50-dccc1002c00d              10
# 2962  2025-04-01  7ee76b50-8c0e-4b8a-8fc6-5ce47d826e86               1
#
#       qtdeDias  mediaTransacoesDias  saldoPontos  qtdePontosPos  \
# 5309         1             2.000000            2              2
# 990        254            27.181102         4419          27319
# 1040         1             1.000000           50             50
# 1684         5             2.000000          206            206
# 2962         1             1.000000           50             50
#
#       qtdePontosNeg  qtdeDiasUltimaTransacao  qtdeDiasPrimeiraTransacao  ...  \
# ...

# %%
model = model_df['model']
features = model_df['features']
predicao = model.predict_proba(amostra[features])[:,1]
amostra['probabilidade_churn'] = predicao
amostra
# Out:
#            dtRef                             idUsuario  qtdeTransacoes  \
# 5309  2025-04-01  f48aa032-94dc-4d0f-9b0f-7f61d5f913cf               2
# 990   2025-04-01  24782f0b-4683-4f35-976a-ea21d6714ba6            6904
# 1040  2025-04-01  268ed8e7-3c04-4865-8594-8d0254954a35               1
# 1684  2025-04-01  433a5751-70f6-4329-be50-dccc1002c00d              10
# 2962  2025-04-01  7ee76b50-8c0e-4b8a-8fc6-5ce47d826e86               1
#
#       qtdeDias  mediaTransacoesDias  saldoPontos  qtdePontosPos  \
# 5309         1             2.000000            2              2
# 990        254            27.181102         4419          27319
# 1040         1             1.000000           50             50
# 1684         5             2.000000          206            206
# 2962         1             1.000000           50             50
#
#       qtdePontosNeg  qtdeDiasUltimaTransacao  qtdeDiasPrimeiraTransacao  ...  \
# ...
