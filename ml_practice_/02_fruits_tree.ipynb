# %%
import pandas as pd

df = pd.read_excel("dados_frutas.xlsx")
df
# Out:
#    Arredondada  Suculenta  Vermelha  Doce    Fruta
# 0            0          1         1     1  Morango
# 1            1          0         0     0    Limão
# 2            1          1         0     1     Pera
# 3            0          0         0     1   Banana
# 4            1          1         1     1   Cereja
# 5            1          1         1     0   Tomate
# 6            1          1         1     1     Maçã

# %% [markdown]
# ### Manual DataFrame Creation
#
# Below is an example of how the `df` DataFrame could be manually created using a dictionary, rather than loading it from an Excel file. This illustrates the structure and content of the data.

# %%
data = {
    'Arredondada': [0, 1, 1, 0, 1, 1, 1],
    'Suculenta': [1, 0, 1, 0, 1, 1, 1],
    'Vermelha': [1, 0, 0, 0, 1, 1, 1],
    'Doce': [1, 0, 1, 1, 1, 0, 1],
    'Fruta': ['Morango', 'Limão', 'Pera', 'Banana', 'Cereja', 'Tomate', 'Maçã']
}
df_manual = pd.DataFrame(data)
display(df_manual)
# Out:
#    Arredondada  Suculenta  Vermelha  Doce    Fruta
# 0            0          1         1     1  Morango
# 1            1          0         0     0    Limão
# 2            1          1         0     1     Pera
# 3            0          0         0     1   Banana
# 4            1          1         1     1   Cereja
# 5            1          1         1     0   Tomate
# 6            1          1         1     1     Maçã

# %%
from sklearn import tree
arvore = tree.DecisionTreeClassifier(random_state=42)
# Random state

# %%
y = df['Fruta']
caracteristicas = ['Arredondada','Suculenta','Vermelha','Doce']

x = df[caracteristicas]

# %%
arvore.fit(x, y) # Ajustar o modelo, ele irá criar a árvore com base nos dados apresentados
# As covariaveis e variaveis repostas
# Aqui ele reconhecerá os padrões
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Exemplo de predição:
arvore.predict([[1,1,1,1]])
# 1: Arredondada
# 1: Suculenta
# 1: Vermelha
# 1: Doce
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Cereja'], dtype=object)

# %%
# Exemplo de predição:
arvore.predict([[0,1,1,0]])
# 0: Não Arredondada
# 1: Suculenta
# 1: Não Vermelha
# 0: Não Doce
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Morango'], dtype=object)

# %%
# Exemplo de predição:
arvore.predict([[0,0,0,0]])
# 0: Não Arredondada
# 0: Não Suculenta
# 0: Não Vermelha
# 0: Não Doce
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Banana'], dtype=object)

# %%
# Como desenhar a árvore

import matplotlib.pyplot as plt

plt.figure(dpi=400) #

tree.plot_tree(arvore, feature_names=caracteristicas,
               class_names=arvore.classes_, # pegando classes distintas e ordenadas
               filled=True
               )
# Out:
# [Text(0.4090909090909091, 0.875, 'Arredondada <= 0.5\ngini = 0.857\nsamples = 7\nvalue = [1, 1, 1, 1, 1, 1, 1]\nclass = Banana'),
#  Text(0.18181818181818182, 0.625, 'Suculenta <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 1, 0, 0]\nclass = Banana'),
#  Text(0.29545454545454547, 0.75, 'True  '),
#  Text(0.09090909090909091, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Banana'),
#  Text(0.2727272727272727, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Morango'),
#  Text(0.6363636363636364, 0.625, 'Vermelha <= 0.5\ngini = 0.8\nsamples = 5\nvalue = [0, 1, 1, 1, 0, 1, 1]\nclass = Cereja'),
#  Text(0.5227272727272727, 0.75, '  False'),
#  Text(0.45454545454545453, 0.375, 'Suculenta <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1, 0]\nclass = Limão'),
#  Text(0.36363636363636365, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Limão'),
# ...

# %%
# value = 1,1,1,1,1,1 # Classes
# Banana # Value: Primeira na Ordem alfabética
# Arredondada menor do que 0,5 = Não Arrendondada
# Não arrendodada: 2
# Suculenta?
# Não suculenta: Banana, Suculenta: Morango

# %%
# Predict proba para visualizar todos:
proba = arvore.predict_proba([[1,1,1,1]])[0]
pd.Series(proba, index=arvore.classes_)
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# Banana     0.0
# Cereja     0.5
# Limão      0.0
# Maçã       0.5
# Morango    0.0
# Pera       0.0
# Tomate     0.0
# dtype: float64

# %% [markdown]
# # Code Summary
#
# This section summarizes all the Python code cells present in this notebook.
#
# ### Cell FR2HaEBT1bhG: Load Data and Display DataFrame
# ```python
# import pandas as pd
#
# df = pd.read_excel("dados_frutas.xlsx")
# df
# ```
#
# ### Cell d3853a3d: Manual DataFrame Creation
# ```python
# data = {
#     'Arredondada': [0, 1, 1, 0, 1, 1, 1],
#     'Suculenta': [1, 0, 1, 0, 1, 1, 1],
#     'Vermelha': [1, 0, 0, 0, 1, 1, 1],
#     'Doce': [1, 0, 1, 1, 1, 0, 1],
#     'Fruta': ['Morango', 'Limão', 'Pera', 'Banana', 'Cereja', 'Tomate', 'Maçã']
# }
# df_manual = pd.DataFrame(data)
# display(df_manual)
# ```
#
# ### Cell 3ZYYY_vH1u1H: Initialize Decision Tree Classifier
# ```python
# from sklearn import tree
# arvore = tree.DecisionTreeClassifier(random_state=42)
# # Random state
# ```
#
# ### Cell U_HFkJtS10qV: Prepare Features and Target
# ```python
# y = df['Fruta']
# caracteristicas = ['Arredondada','Suculenta','Vermelha','Doce']
#
# x = df[caracteristicas]
# ```
#
# ### Cell BX2LbXol2Ul-: Fit Decision Tree Model
# ```python
# arvore.fit(x, y) # Ajustar o modelo, ele irá criar a árvore com base nos dados apresentados
# # As covariaveis e variaveis repostas
# # Aqui ele reconhecerá os padrões
# ```
#
# ### Cell 4-byXBJu21DH: Example Prediction 1
# ```python
# # Exemplo de predição:
# arvore.predict([[1,1,1,1]])
# # 1: Arredondada
# # 1: Suculenta
# # 1: Vermelha
# # 1: Doce
# ```
#
# ### Cell XljM6zi_3Bos: Example Prediction 2
# ```python
# # Exemplo de predição:
# arvore.predict([[0,1,1,0]])
# # 0: Não Arredondada
# # 1: Suculenta
# # 1: Não Vermelha
# # 0: Não Doce
# ```
#
# ### Cell JYEd4dmK3mB0: Example Prediction 3
# ```python
# # Exemplo de predição:
# arvore.predict([[0,0,0,0]])
# # 0: Não Arredondada
# # 0: Não Suculenta
# # 0: Não Vermelha
# # 0: Não Doce
# ```
#
# ### Cell o1AFCAa239Pr: Plot Decision Tree
# ```python
# # Como desenhar a árvore
#
# import matplotlib.pyplot as plt
#
# plt.figure(dpi=400) #
#
# tree.plot_tree(arvore, feature_names=caracteristicas,
#                class_names=arvore.classes_, # pegando classes distintas e ordenadas
#                filled=True
#                )
# ```
#
# ### Cell 3B52mFJn5FdL: Commented Notes
# ```python
# # value = 1,1,1,1,1,1 # Classes
# # Banana # Value: Primeira na Ordem alfabética
# # Arredondada menor do que 0,5 = Não Arrendodada
# # Não arrendodada: 2
# # Suculenta?
# # Não suculenta: Banana, Suculenta: Morango
# ```
#
# ### Cell GJdTNtrM6PM2: Predict Probabilities
# ```python
# # Predict proba para visualizar todos:
# proba = arvore.predict_proba([[1,1,1,1]])[0]
# pd.Series(proba, index=arvore.classes_)
# ```
